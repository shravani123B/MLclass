# %%
import pandas as pd 
data=pd.read_csv("student_scores.csv")
data.head(10)
# Out:
#      name  hours  score gender grades class
# 0   Aarav      8     76      M      A    9A
# 1    Riya      5     62      F      B    9B
# 2   Kabir     10     88      M      A   10A
# 3    Sana      4     55      F      C    9A
# 4  Vivaan      7     72      M      B   10B
# 5  Ishita      6     64      F      B    9C
# 6   Rohan      3     48      M      D    9B
# 7   Meera      9     90      F      A   11A
# 8  Aditya      2     38      M      F    9C
# 9   Kavya     11     93      F      A   12A

# %%
print('Columns:', data.columns.tolist())
print('\nInfo:')
print(data.info())
print('\nDescribe:')
display(data.describe())
# Out:
# Columns: ['name', 'hours', 'score', 'gender', 'grades', 'class']
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    92 non-null     object
#  1   hours   92 non-null     int64
#  2   score   92 non-null     int64
#  3   gender  92 non-null     object
#  4   grades  92 non-null     object
#  5   class   92 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 4.4+ KB
# None
#
# Describe:
#            hours      score
# count  92.000000  92.000000
# mean    6.510870  68.836957
# std     2.265336  15.692286
# min     2.000000  35.000000
# 25%     5.000000  57.000000
# 50%     7.000000  70.000000
# 75%     8.000000  82.000000
# max    11.000000  94.000000

# %%
#completness
print(data.isnull().sum())
# Out:
# name      0
# hours     0
# score     0
# gender    0
# grades    0
# class     0
# dtype: int64

# %%
import pandas as pd 
data=pd.read_csv("student_scores.csv")
#Option 1: Fill missing values with mean
#data["score"] = data["score"].fillna (data["score"].mean())
#Option 2: Drop rows with missing values
data = data.dropna()
print(data)
# Out:
#        name  hours  score gender grades class
# 0     Aarav      8     76      M      A    9A
# 1      Riya      5     62      F      B    9B
# 2     Kabir     10     88      M      A   10A
# 3      Sana      4     55      F      C    9A
# 4    Vivaan      7     72      M      B   10B
# ..      ...    ...    ...    ...    ...   ...
# 87   Prisha      4     52      F      C    9A
# 88     Neil     10     88      M      A   12C
# 89    Rutvi      7     73      F      B   10A
# 90  Harshit      5     57      M      C    9B
# 91   Vritti      8     81      F      A   11B
#
# [92 rows x 6 columns]

# %%
import pandas as pd 
data=pd.read_csv("student_scores.csv")
#Option 1: Fill missing values with mean
#data["score"] = data["score"].fillna (data["score"].mean())
#Option 2: Drop rows with missing values
data = data.dropna()
print(data)
# Out:
#        name  hours  score gender grades class
# 0     Aarav      8     76      M      A    9A
# 1      Riya      5     62      F      B    9B
# 2     Kabir     10     88      M      A   10A
# 3      Sana      4     55      F      C    9A
# 4    Vivaan      7     72      M      B   10B
# ..      ...    ...    ...    ...    ...   ...
# 87   Prisha      4     52      F      C    9A
# 88     Neil     10     88      M      A   12C
# 89    Rutvi      7     73      F      B   10A
# 90  Harshit      5     57      M      C    9B
# 91   Vritti      8     81      F      A   11B
#
# [92 rows x 6 columns]

# %%
data.shape
# Out:
# (92, 6)

# %%
#Dataset Consistency
data.dtypes
# Out:
# name      object
# hours      int64
# score      int64
# gender    object
# grades    object
# class     object
# dtype: object

# %%
#accuracy
data.describe()
# Out:
#            hours      score
# count  92.000000  92.000000
# mean    6.510870  68.836957
# std     2.265336  15.692286
# min     2.000000  35.000000
# 25%     5.000000  57.000000
# 50%     7.000000  70.000000
# 75%     8.000000  82.000000
# max    11.000000  94.000000

# %%
data.describe()
data['score'].plot(kind='box')
# Out:
# <Axes: >

# %%
#TIME-KEEPING - Is the data up-to-date?
data['score'].max()
data['score'].min()
# Out:
# 35

# %%
#biased check
data['grades'].value_counts(normalize=True)
data['grades'].value_counts(normalize=True)
# Out:
# grades
# B    0.358696
# A    0.326087
# C    0.195652
# D    0.086957
# F    0.032609
# Name: proportion, dtype: float64

# %% [markdown]
# | **Field**           | **Details** |
# |---------------------|-------------|
# | **Dataset Name**    | `student_performance_data.csv` |
# | **Description**     | Dataset of 92 students containing study hours, exam scores, gender, grades, and class. Used for Data Quality assessment (Completeness, Accuracy, Consistency, Bias, Time-Keeping). |
# | **Rows**            | 92 |
# | **Columns**         | 6 |
# | **Features**        | `name`, `hours`, `score`, `gender`, `grades`, `class` |
# | **Target Variable** | `score` *(if used for prediction tasks)* |
# | **Owner**           | Student / Notebook Author |
# | **Last Updated**    | 2025-12-09 |

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the encoder
le = LabelEncoder()

# Transform the 'gender' column
data["gender"] = le.fit_transform(data['gender'])

# Display first 20 rows
print(data.head(20))
# Out:
#        name  hours  score  gender grades class
# 0     Aarav      8     76       1      A    9A
# 1      Riya      5     62       0      B    9B
# 2     Kabir     10     88       1      A   10A
# 3      Sana      4     55       0      C    9A
# 4    Vivaan      7     72       1      B   10B
# 5    Ishita      6     64       0      B    9C
# 6     Rohan      3     48       1      D    9B
# 7     Meera      9     90       0      A   11A
# 8    Aditya      2     38       1      F    9C
# 9     Kavya     11     93       0      A   12A
# 10    Naman      5     60       1      B   10A
# 11   Jhanvi      7     70       0      B   11B
# 12   Pranav      4     52       1      C    9A
# 13     Tara      9     85       0      A   12B
# 14     Yash      6     66       1      B   10C
# 15    Anaya      8     78       0      A   11A
# 16    Harsh      3     45       1      D    9A
# 17     Diya     10     89       0      A   12C
# 18  Sarthak      6     63       1      B   10B
# ...

# %%
import pandas as pd

data = """customer_id,region,plan_type,tenure_months,monthly_charges,total_charges,calls_dropped,support_calls,is_prepaid,complaints_last_30_days,call_drop_ratio,is_ported_out_last_year,days_since_last_recharge,last_call_time,first_recharge_date,churn
C001,North,Basic,12,399,4788,3,1,Yes,1,0.08,No,12,2025-01-18 21:15:42,2024-12-20,No
C002,West,Premium,4,899,3596,1,0,No,2,0.15,Yes,25,2025-01-17 18:22:30,2025-01-02,Yes
C003,South,Standard,22,599,13178,0,2,No,0,0.05,No,40,2025-01-16 20:10:45,2024-11-25,No
C004,East,Basic,8,349,2792,4,3,Yes,4,0.22,No,60,2025-01-15 09:12:15,2024-12-10,Yes
C005,Central,Premium,15,999,14985,2,1,No,3,0.10,Yes,30,2025-01-14 11:45:22,2024-12-30,No
C006,North,Standard,6,549,3294,0,0,Yes,1,0.07,No,5,2025-01-18 06:33:55,2025-01-12,No
C007,West,Basic,3,299,897,5,4,Yes,5,0.25,Yes,75,2025-01-13 08:18:20,2024-11-01,Yes
C008,South,Premium,18,899,16182,1,1,No,1,0.11,No,45,2025-01-19 10:11:59,2024-12-10,No
C009,East,Standard,27,649,17523,0,2,No,0,0.05,No,15,2025-01-17 23:09:31,2025-01-01,No
C010,Central,Basic,11,399,4389,3,1,Yes,2,0.14,No,20,2025-01-18 17:45:50,2024-12-25,Yes
"""

# Write to local file in Colab runtime
with open("telecom_dataset.csv", "w") as f:
    f.write(data)

print("telecom_dataset.csv saved successfully!")

df = pd.read_csv("telecom_dataset.csv", parse_dates=['last_call_time','first_recharge_date'])
df.head()
# Out:
# telecom_dataset.csv saved successfully!
#   customer_id   region plan_type  tenure_months  monthly_charges  \
# 0        C001    North     Basic             12              399
# 1        C002     West   Premium              4              899
# 2        C003    South  Standard             22              599
# 3        C004     East     Basic              8              349
# 4        C005  Central   Premium             15              999
#
#    total_charges  calls_dropped  support_calls is_prepaid  \
# 0           4788              3              1        Yes
# 1           3596              1              0         No
# 2          13178              0              2         No
# 3           2792              4              3        Yes
# 4          14985              2              1         No
#
#    complaints_last_30_days  call_drop_ratio is_ported_out_last_year  \
# 0                        1             0.08                      No
# ...

# %%
data="""customer_id,region,plan_type,tenure_months,monthly_charges,total_charges,calls_dropped,support_calls,is_prepaid,complaints_last_30_days,call_drop_ratio,is_ported_out_last_year,days_since_first_recharge,days_since_last_recharge,last_call_time,first_recharge_date,network_issue_flag,data_usage_intensity,days_to_churn_prediction,churn
111,Chennai,Postpaid,28,459,17672,3,1,No,5,0.083,No,1728,47,"14:32",4/8/2020,Yes,Medium,12,No
111,Chennai,Postpaid,5,459,1665,0,5,No,0,0,No,1437,0,"00:54",4/8/2020,No,Low,95,Yes
"""

# %%
import pandas as pd
df = pd.read_csv("telecom_dataset.csv")

# %%
# Features = input columns; Label = output column
features = df.drop(columns=['churn'])
label = df['churn']

print("Feature Columns:")
[print (x) for x in features.columns]
print("\n\nLabel Column:\n",label.name)
# Out:
# Feature Columns:
# customer_id
# region
# plan_type
# tenure_months
# monthly_charges
# total_charges
# calls_dropped
# support_calls
# is_prepaid
# complaints_last_30_days
# call_drop_ratio
# is_ported_out_last_year
# days_since_last_recharge
# last_call_time
# first_recharge_date
#
#
# Label Column:
#  churn

# %%
categorical = df.select_dtypes(include='object').columns
numerical = df.select_dtypes(exclude='object').columns

print("Categorical Features:", list(categorical))
print("Numerical Features:", list(numerical))
# Out:
# Categorical Features: ['customer_id', 'region', 'plan_type', 'is_prepaid', 'is_ported_out_last_year', 'last_call_time', 'first_recharge_date', 'churn']
# Numerical Features: ['tenure_months', 'monthly_charges', 'total_charges', 'calls_dropped', 'support_calls', 'complaints_last_30_days', 'call_drop_ratio', 'days_since_last_recharge']

# %%
from sklearn.preprocessing import OneHotEncoder,LabelEncoder,StandardScaler,MinMaxScaler
le=LabelEncoder()
df['region_encoded']=le.fit_transform(df['region'])
df[['region','region_encoded']].head()
# Out:
#     region  region_encoded
# 0    North               2
# 1     West               4
# 2    South               3
# 3     East               1
# 4  Central               0

# %%
# Display original categorical columns
print("Original categorical columns:", df.select_dtypes(include='object').columns.tolist())
print(df[['plan_type']])

# One-hot encode the 'plan_type' column
df_onehot = pd.get_dummies(df, columns=['plan_type'], prefix='plan')

#from sklearn.preprocessing import OneHotEncoder
#encoder = OneHotEncoder(sparse=False)
#encoded = encoder.fit_transform(df[['plan_type']])

# Automatically detect new dummy columns
plan_columns = [col for col in df_onehot.columns if col.startswith('plan_')]
print(list(plan_columns))

# Display first few rows of new encoded columns
print("\nEncoded plan_type columns:\n")
print(df_onehot[plan_columns].head())
# Out:
# Original categorical columns: ['customer_id', 'region', 'plan_type', 'is_prepaid', 'is_ported_out_last_year', 'last_call_time', 'first_recharge_date', 'churn']
#   plan_type
# 0     Basic
# 1   Premium
# 2  Standard
# 3     Basic
# 4   Premium
# 5  Standard
# 6     Basic
# 7   Premium
# 8  Standard
# 9     Basic
# ['plan_Basic', 'plan_Premium', 'plan_Standard']
#
# Encoded plan_type columns:
#
#    plan_Basic  plan_Premium  plan_Standard
# 0        True         False          False
# 1       False          True          False
# 2       False         False           True
# 3        True         False          False
# 4       False          True          False

# %%
# Mutual Information (Feature Importance)

mi = mutual_info_classif(X, y, discrete_features=False, random_state=42)

importance = (
    pd.DataFrame({'Feature': X.columns, 'MI_Score': mi})
    .sort_values(by='MI_Score', ascending=False)
    .reset_index(drop=True)
)

print("Mutual Information Scores:\n")
print(importance)

# Plot Mutual Information Scores
plt.figure(figsize=(8, 5))
sns.barplot(data=importance, x='MI_Score', y='Feature', palette='viridis')
plt.title("Feature Importance (Mutual Information)")
plt.xlabel("Mutual Information Score")
plt.ylabel("Feature")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[106], line 3
#       1 # Mutual Information (Feature Importance)
# ----> 3 mi = mutual_info_classif(X, y, discrete_features=False, random_state=42)
#       5 importance = (
#       6     pd.DataFrame({'Feature': X.columns, 'MI_Score': mi})
#       7     .sort_values(by='MI_Score', ascending=False)
#       8     .reset_index(drop=True)
#       9 )
#      11 print("Mutual Information Scores:\n")
#
# NameError: name 'mutual_info_classif' is not defined

# %%
minmax = MinMaxScaler()
df[['tenure_norm','charges_norm']] = minmax.fit_transform(df[['tenure_months','monthly_charges']])
df[['tenure_months','tenure_norm','monthly_charges','charges_norm']].head()


xmax=df['monthly_charges'].max()
xmin=df['monthly_charges'].min()
print(xmin,xmax)
xnor = (399 - xmin)/(xmax-xmin)
print("xnormalized:",xnor)

df[['tenure_months','tenure_norm','monthly_charges','charges_norm']].head()
# Out:
# 299 999
# xnormalized: 0.14285714285714285
#    tenure_months  tenure_norm  monthly_charges  charges_norm
# 0             12     0.375000              399      0.142857
# 1              4     0.041667              899      0.857143
# 2             22     0.791667              599      0.428571
# 3              8     0.208333              349      0.071429
# 4             15     0.500000              999      1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.hist(x=df[['monthly_charges']], bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Monthly Charges')
plt.ylabel('Frequency')
plt.title('Distribution of Monthly Charges')
plt.show()

plt.figure(figsize=(8,6))
plt.hist(x=df[['charges_norm']], bins=20, color='skyblue', edgecolor='black')
plt.xlabel('charges_norm ')
plt.ylabel('Frequency')
plt.title('Distribution of charges_norm')
plt.show()

# %%
scaler = StandardScaler()
df[['monthly_scaled','total_scaled']] = scaler.fit_transform(df[['monthly_charges','total_charges']])
df[['monthly_charges','monthly_scaled','total_charges','total_scaled']].head()
# Out:
#    monthly_charges  monthly_scaled  total_charges  total_scaled
# 0              399       -0.853241           4788     -0.550711
# 1              899        1.227835           3596     -0.745248
# 2              599       -0.020811          13178      0.818559
# 3              349       -1.061349           2792     -0.876463
# 4              999        1.644050          14985      1.113466

# %%
import pandas as pd

# Ensure datetime columns
df['last_call_time'] = pd.to_datetime(df['last_call_time'])
df['first_recharge_date'] = pd.to_datetime(df['first_recharge_date'])

# Extract year, month, and weekday from last_call_time
df['call_year'] = df['last_call_time'].dt.year
df['call_month'] = df['last_call_time'].dt.month
df['call_weekday'] = df['last_call_time'].dt.day_name()

# Calculate days since first recharge relative to 2025-01-20
reference_date = pd.to_datetime("2025-01-20")
df['days_since_first_recharge'] = (reference_date - df['first_recharge_date']).dt.days

# Display selected columns
df[['customer_id', 'last_call_time', 'first_recharge_date', 'days_since_first_recharge']].head()
# Out:
#   customer_id      last_call_time first_recharge_date  \
# 0        C001 2025-01-18 21:15:42          2024-12-20
# 1        C002 2025-01-17 18:22:30          2025-01-02
# 2        C003 2025-01-16 20:10:45          2024-11-25
# 3        C004 2025-01-15 09:12:15          2024-12-10
# 4        C005 2025-01-14 11:45:22          2024-12-30
#
#    days_since_first_recharge
# 0                         31
# 1                         18
# 2                         56
# 3                         41
# 4                         21

# %%
# Ensure columns are strings (optional but safe)
df['plan_type'] = df['plan_type'].astype(str)
df['region'] = df['region'].astype(str)

# Combine plan_type and region into a new feature
df['plan_region'] = df['plan_type'] + "_" + df['region']

# Display first 5 rows
df[['plan_type', 'region', 'plan_region']].head()
# Out:
#   plan_type   region      plan_region
# 0     Basic    North      Basic_North
# 1   Premium     West     Premium_West
# 2  Standard    South   Standard_South
# 3     Basic     East       Basic_East
# 4   Premium  Central  Premium_Central
